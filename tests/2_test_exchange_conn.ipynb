# %%
# Adicionar o path do projeto ao sys.path
import sys
from pathlib import Path

# %%
# Suprimir warnings
import warnings

warnings.filterwarnings("ignore")

# Pega o diretório raiz do projeto (ajuste o número de . parent conforme necessário)
project_root = Path.cwd()  # Se precisar subir mais níveis, adicione mais . parent
# ou
# project_root = Path(__file__).parent.parent  # Se estiver em um arquivo . py

# Adiciona ao path se ainda não estiver lá
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# Verificar se funcionou (opcional)
print(f"Path do projeto adicionado: {project_root}")
# Out:
# Path do projeto adicionado: /home/ics/Projetos_Python/crypto-bot

# %% [markdown]
# ### Não Usar: "Restart"
# ### Use → ( Ctrl + Shft + P) → Reload Window

# %%
from src.core.exchange_conn import Exchange

# %%
exchange = Exchange()
# Out:
# [01/08/26 14:35:59] INFO     [EXCHANGE_CONN] Conectando à BINANCE...
# [01/08/26 14:35:59] INFO     [EXCHANGE_CONN] Modo: TESTNET
# [01/08/26 14:36:04] ERROR    [EXCHANGE_CONN] Erro de autenticação: verifique suas chaves de API - binance
#                              {"code":-2014,"msg":"API-key format invalid."}
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 exchange = Exchange()
#
# File ~/Projetos_Python/crypto-bot/src/core/exchange_conn.py:48, in Exchange.__init__(self)
#      46 log_exchange.info(f"Modo: {'TESTNET' if settings.sandbox else 'REAL'}")
#      47 self.exchange_class = getattr(ccxt, settings.exchange)  # ← retorna a CLASSE
# ---> 48 self.client = self._get_exchange()
#
# File ~/Projetos_Python/crypto-bot/src/core/exchange_conn.py:124, in Exchange._get_exchange(self)
#     122 exchange = self._create_ccxt_instance()
#     123 if not self._test_connection(exchange):
# --> 124     raise ConnectionError(
#     125         "Falha ao conectar com a exchange - verifique os logs acima"
#     126     )
#     127 return exchange
#
# ConnectionError: Falha ao conectar com a exchange - verifique os logs acima
